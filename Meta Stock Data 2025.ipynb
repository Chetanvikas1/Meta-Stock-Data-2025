# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Path to your zip file in Google Drive
zip_path = '/content/archive.zip'

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/meta_stock_data_2025')

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/archive.zip')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.084515
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   33.900501
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   30.882032
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   31.878227
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   32.904308
# ...          ...         ...         ...         ...         ...         ...
# 3181  2025-01-13  607.099976  608.969971  598.450012  608.330017  608.330017
# 3182  2025-01-14  605.070007  605.489990  588.549988  594.250000  594.250000
# 3183  2025-01-15  610.210022  622.460022  606.500000  617.119995  617.119995
# 3184  2025-01-16  611.500000  616.250000  609.710022  611.299988  611.299988
# 3185  2025-01-17  624.049988  624.969971  603.669983  612.770020  612.770020
#
#          Volume
# 0     573576400
# ...

# %%
df.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2012-05-18  42.049999  45.000000  38.000000  38.230000  38.084515
# 1  2012-05-21  36.529999  36.660000  33.000000  34.029999  33.900501
# 2  2012-05-22  32.610001  33.590000  30.940001  31.000000  30.882032
# 3  2012-05-23  31.370001  32.500000  31.360001  32.000000  31.878227
# 4  2012-05-24  32.950001  33.209999  31.770000  33.029999  32.904308
# 5  2012-05-25  32.900002  32.950001  31.110001  31.910000  31.788570
# 6  2012-05-29  31.480000  31.690001  28.650000  28.840000  28.730253
# 7  2012-05-30  28.700001  29.549999  27.860001  28.190001  28.082726
# 8  2012-05-31  28.549999  29.670000  26.830000  29.600000  29.487360
# 9  2012-06-01  28.889999  29.150000  27.389999  27.719999  27.614515
#
#       Volume
# 0  573576400
# 1  168192700
# 2  101786600
# 3   73600000
# 4   50237200
# 5   37149800
# 6   78063400
# 7   57267900
# 8  111639200
# 9   41855500

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3186.000000  3186.000000  3186.000000  3186.000000  3186.000000
# mean    186.993983   189.388905   184.632693   187.066114   186.438467
# std     132.340763   133.933605   130.660796   132.345106   132.074638
# min      18.080000    18.270000    17.549999    17.730000    17.662531
# 25%      88.697502    89.837500    87.494997    88.410002    88.073563
# 50%     165.914993   168.315002   163.750000   166.010002   165.378258
# 75%     246.732498   250.099995   244.490002   246.822506   245.883259
# max     631.700012   638.400024   627.210022   632.679993   632.170044
#
#              Volume
# count  3.186000e+03
# mean   2.928538e+07
# std    2.575548e+07
# min    4.726100e+06
# 25%    1.542828e+07
# 50%    2.167915e+07
# 75%    3.341255e+07
# max    5.735764e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3186 entries, 0 to 3185
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3186 non-null   object
#  1   Open       3186 non-null   float64
#  2   High       3186 non-null   float64
#  3   Low        3186 non-null   float64
#  4   Close      3186 non-null   float64
#  5   Adj Close  3186 non-null   float64
#  6   Volume     3186 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 174.4+ KB

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
pip install summarytools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.0 MB/s eta 0:00:00
# ...

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_f1066 thead>tr>th {
#   text-align: left;
# }
# #T_f1066_row0_col0, #T_f1066_row1_col0, #T_f1066_row2_col0, #T_f1066_row3_col0, #T_f1066_row4_col0, #T_f1066_row5_col0, #T_f1066_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_f1066_row0_col1, #T_f1066_row1_col1, #T_f1066_row2_col1, #T_f1066_row3_col1, #T_f1066_row4_col1, #T_f1066_row5_col1, #T_f1066_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_f1066_row0_col2, #T_f1066_row1_col2, #T_f1066_row2_col2, #T_f1066_row3_col2, #T_f1066_row4_col2, #T_f1066_row5_col2, #T_f1066_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# ...

# %%
df.shape
# Out:
# (3186, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Date         3186
# Open         2982
# High         2984
# Low          2989
# Close        3019
# Adj Close    3020
# Volume       3178
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.describe(include='all')
# Out:
#               Date         Open         High          Low        Close  \
# count         3186  3186.000000  3186.000000  3186.000000  3186.000000
# unique        3186          NaN          NaN          NaN          NaN
# top     2012-05-18          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN   186.993983   189.388905   184.632693   187.066114
# std            NaN   132.340763   133.933605   130.660796   132.345106
# min            NaN    18.080000    18.270000    17.549999    17.730000
# 25%            NaN    88.697502    89.837500    87.494997    88.410002
# 50%            NaN   165.914993   168.315002   163.750000   166.010002
# 75%            NaN   246.732498   250.099995   244.490002   246.822506
# max            NaN   631.700012   638.400024   627.210022   632.679993
#
#           Adj Close        Volume
# count   3186.000000  3.186000e+03
# unique          NaN           NaN
# ...

# %%
#Outlier Removal Using Z-Scores

# %%
#Let's calculate Z-Scores of each value in the Data Frame, in order to detect outliers.

# %%
from scipy import stats

z_scores = stats.zscore(df.select_dtypes(include=['float64', 'int64']))
z_scores
# Out:
#           Open      High       Low     Close  Adj Close     Volume
# 0    -1.095405 -1.078233 -1.122416 -1.124783  -1.123435  21.136333
# 1    -1.137122 -1.140512 -1.160689 -1.156523  -1.155119   5.394157
# 2    -1.166747 -1.163437 -1.176457 -1.179421  -1.177977   2.815424
# 3    -1.176118 -1.171577 -1.173242 -1.171864  -1.170433   1.720860
# 4    -1.164178 -1.166275 -1.170104 -1.164080  -1.162663   0.813617
# ...        ...       ...       ...       ...        ...        ...
# 3181  3.174925  3.133246  3.167609  3.183571   3.194843  -0.718421
# 3182  3.159583  3.107259  3.091828  3.077166   3.088220  -0.609185
# 3183  3.198429  3.233984  3.229228  3.249998   3.261407  -0.534381
# 3184  3.208177  3.187610  3.253800  3.206016   3.217334  -0.812773
# 3185  3.303023  3.252727  3.207566  3.217125   3.228466  -0.467600
#
# [3186 rows x 6 columns]

# %%
df_outliers = df[(z_scores > 3).any(axis=1) | (z_scores < -3).any(axis=1)]
print(f"The number of outlier rows: {df_outliers.shape[0]}")
# Out:
# The number of outlier rows: 96

# %%
df_no_outliers = df[(z_scores < 3).all(axis=1) & (z_scores > -3).all(axis=1)]
print(f"Number of rows after outlier removal: {df_no_outliers.shape[0]}")
# Out:
# Number of rows after outlier removal: 3090

# %%
df['Close'].min()
# Out:
# 17.729999542236328

# %%
df[df['Close']==df['Close'].min()]
# Out:
#           Date   Open   High        Low  Close  Adj Close    Volume
# 74  2012-09-04  18.08  18.27  17.549999  17.73  17.662531  46622400

# %%
df[df['Close']==df['Close'].max()]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3161  2024-12-11  623.369995  638.400024  621.530029  632.679993  632.170044
#
#         Volume
# 3161  10837200

# %%
df[df['Volume']==df['Volume'].min()]
# Out:
#             Date        Open       High         Low   Close  Adj Close  \
# 3170  2024-12-24  602.719971  607.98999  599.280029  607.75     607.75
#
#        Volume
# 3170  4726100

# %%
df[df['Volume']==df['Volume'].max()]
# Out:
#          Date       Open  High   Low  Close  Adj Close     Volume
# 0  2012-05-18  42.049999  45.0  38.0  38.23  38.084515  573576400

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Box Plots

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Close'], color='grey')

plt.title('Box Plot of Closing Price', fontsize=16)
plt.xlabel('Closing Price', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Volume'], color='orange')

plt.title('Box Plot of Volume Traded', fontsize=16)
plt.xlabel('Volume Traded in the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['High'], color='teal')

plt.title('Box Plot of Highest Price', fontsize=16)
plt.xlabel('Highest Price of the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Low'], color='khaki')

plt.title('Box Plot of Lowest Price', fontsize=16)
plt.xlabel('Lowest Price of the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Open'], color='yellowgreen')

plt.title('Box Plot of Opening Price', fontsize=16)
plt.xlabel('Opening Price of the Day', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Adj Close'], color='turquoise')

plt.title('Box Plot of Adjusted Close', fontsize=16)
plt.xlabel('Adjusted Close', fontsize=14)

plt.show()

# %%
#Joint Plot of Closing Price & Volume Traded

# %%
sns.jointplot(x='Volume', y='Close', data=df_no_outliers, color='teal')
plt.suptitle('Joint Plot of Closing Price and Volume Traded', y=1.02)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df, x='Volume', shade=True, color='gold')
plt.title('Density Plot of Volume')
plt.xlabel('Volume')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df, x='Close', shade=True, color='silver')
plt.title('Density Plot of Closing Price')
plt.xlabel('Closing Price')
plt.ylabel('Density')
plt.show()

# %%
#Regression Plot of Closing Price vs. Volume

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='Volume', y='Close', data=df_no_outliers, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Closing Price vs. Volume')
plt.xlabel('Volume')
plt.ylabel('Closing Price')
plt.show()

# %%
#Closing Price (USD) vs. Date of META Stock

# %%
df['Date']= pd.to_datetime(df['Date'])
plt.figure(figsize=(10,6))
plt.plot(df['Date'], df['Close'], label='APPLE', color='grey')
plt.title('Stock Price of APPLE', fontsize=19)
plt.xlabel('Date', fontsize=16)
plt.ylabel('Closing Price (USD)', fontsize=16)

plt.xticks(rotation=45)
plt.legend(loc='upper left', fontsize=14)
plt.tight_layout()
plt.show()

# %%
#Volume Traded Over Time¶

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Volume'], label='Volume', color='orange')
plt.title('Volume Traded Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Distribution of Open Price, Close Price & Adjusted Close Price

# %%
plt.figure(figsize=(14, 8))

# Plot Open price distribution
plt.subplot(3, 1, 1)
sns.histplot(df['Open'], kde=True, color='blue', bins=30)
plt.title('Distribution of Open Price', fontsize=14)
plt.xlabel('Price (USD)', fontsize=12)

# Plot Close price distribution
plt.subplot(3, 1, 2)
sns.histplot(df['Close'], kde=True, color='green', bins=30)
plt.title('Distribution of Close Price', fontsize=14)
plt.xlabel('Price (USD)', fontsize=12)

# Plot Adjusted Close price distribution
plt.subplot(3, 1, 3)
sns.histplot(df['Adj Close'], kde=True, color='red', bins=30)
plt.title('Distribution of Adjusted Close Price', fontsize=14)
plt.xlabel('Price (USD)', fontsize=12)

plt.tight_layout()
plt.show()

# %%
#Stock Price with 30-day and 100-day Moving Averages

# %%
df['MA30'] = df['Close'].rolling(window=30).mean()
df['MA100'] = df['Close'].rolling(window=100).mean()

plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue', alpha=0.6)
plt.plot(df['Date'], df['MA30'], label='30-day Moving Average', color='green', linestyle='--')
plt.plot(df['Date'], df['MA100'], label='100-day Moving Average', color='red', linestyle='--')
plt.title('Stock Price with 30-day and 100-day Moving Averages', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
correlation_matrix = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].corr()

plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', linewidths=0.5, fmt='.2f')
plt.title('Correlation Matrix for Stock Prices and Volume for APPLE',fontsize=16)
plt.show()

# %%
sns.pairplot(df)

# %%
#Prediction Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df.isna().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# MA30         29
# MA100        99
# dtype: int64

# %%
features = df.drop(columns=['Date', 'Close', 'MA30', 'MA100'])
target = df['Close']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=29)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

rf_model = RandomForestRegressor(n_estimators=250, random_state=29)

rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=250, random_state=29)

# %%
y_pred_rf = rf_model.predict(X_test_scaled)

y_pred_rf
# Out:
# array([186.18292072, 139.93943988, 302.65147913, 118.72535941,
#        122.60048004, 180.84883966, 217.80295917,  19.10043999,
#         29.07311977, 276.60420862,  65.41147998, 180.41783887,
#        167.30632196,  77.87240012, 201.78884216, 153.2464375 ,
#        130.1166438 , 115.97455933, 495.39752258,  75.17928168,
#         79.0069201 ,  77.0160004 , 171.20767798, 221.76104413,
#         80.6962782 ,  67.6943197 ,  57.58999902, 110.88931802,
#        510.5292804 ,  80.4296008 ,  90.86215936, 150.23064014,
#        615.7205293 , 476.11920483, 174.59147955, 357.81287854,
#        218.07819824, 142.36188153,  82.13048062, 179.69275562,
#         23.93216032, 218.36475964, 229.80212164, 164.93043964,
#        165.97848138, 272.57623401, 213.15020282, 311.68448022,
#        273.69892029, 131.53676019, 362.12424268, 174.57540173,
#         74.67844037, 333.16760205,  64.63751871, 166.97760022,
#        506.92251941, 188.2256001 , 160.66708154, 235.75199707,
# ...

# %%
y_test
# Out:
# 1869    186.149994
# 1214    139.839996
# 2239    302.820007
# 1164    118.690002
# 1058    122.510002
#            ...
# 1791    197.199997
# 1321    167.410004
# 1138    120.379997
# 481      61.240002
# 77       18.980000
# Name: Close, Length: 638, dtype: float64

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

mae_rf, r2_rf
# Out:
# (0.2072580848622099, 0.9999838143077486)

# %%
mean_closing_price = df['Close'].mean()
mean_closing_price

error_percent = (mae_rf/mean_closing_price)*100
error_percent
# Out:
# 0.11079402896980817

# %%
percentage_accuracy_of_closing_price = 100-error_percent
percentage_accuracy_of_closing_price
# Out:
# 99.8892059710302
